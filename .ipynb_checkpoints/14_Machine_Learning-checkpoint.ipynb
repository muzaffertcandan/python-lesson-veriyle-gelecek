# %%
# Makine öğrenmesi bilgisayarın veriler ve istatistiklerden öğrenmesini sağlar

# %%
# Machine Learning, AI 'a giden ilk yoldur
# Machine Learning veriyi analiz edip öğrenerek sonuçları tahmin etmeye çalışan programdır.

# %%
"""
Veri Setleri:
Bilgisayarların mantığına göre, Veriler arraylerden databaselere kadar her şekilde toplanılabilir.
"""

# %%
# Örnek Veri Seti
[99,86,87,88,111,86,103,87,94,78,77,85,86]
# Out:
# [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# %%
# Mean: Ortalama Değer

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)
# Out:
# 89.76923076923077

# %%
#Median: Ortanca değer

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)

# %%
import numpy
#77, 78, 85, 86, 86, 86, 87, 87, 94, 98, 99, 103

(86 + 87) / 2 = 86.5

speed = [99,86,87,88,86,103,87,94,78,77,85,86]

x = numpy.median(speed)

print(x)

# %%
# Mode: En çok tekrar eden değer

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /opt/homebrew/Cellar/jupyterlab/4.0.9_2/libexec/lib/python3.12/site-packages (from scipy) (1.26.4)
# Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 520.7 kB/s eta 0:00:0000:0100:02
# Installing collected packages: scipy
# Successfully installed scipy-1.12.0
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.9_2/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=86, count=3)

# %%
# Standard Deviation
# Standart sapma, değerlerin ne kadar yayıldığını tanımlayan bir sayıdır.
# ortalama değerden ne kadar uzak olduğudur
speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)
y= numpy.mean(speed)
print("x: ",x)
print("y: ",y)
# Out:
# x:  0.9035079029052513
# y:  86.42857142857143

# %%
# example 2:
speed = [32,111,138,28,59,77,97]

x = numpy.std(speed)

print(x)

# %%
# Variance
# varyans değerlerin ne kadar dağıldığını gösteren değerdir
# ve ortalama değerin her bir değerden çıkarılmasıyla bulunur
# varyansın karekökü standart sapmaya eşittir
# (32+111+138+28+59+77+97) / 7 = 77.4 ort değer
"""
 32 - 77.4 = -45.4
111 - 77.4 =  33.6
138 - 77.4 =  60.6
 28 - 77.4 = -49.4
 59 - 77.4 = -18.4
 77 - 77.4 = - 0.4
 97 - 77.4 =  19.6
 """
"""
(-45.4)2 = 2061.16
 (33.6)2 = 1128.96
 (60.6)2 = 3672.36
(-49.4)2 = 2440.36
(-18.4)2 =  338.56
(- 0.4)2 =    0.16
 (19.6)2 =  384.16
 """
# (2061.16+1128.96+3672.36+2440.36+338.56+0.16+384.16) / 7 = 1432.2
# Out:
# '\n(-45.4)2 = 2061.16\n (33.6)2 = 1128.96\n (60.6)2 = 3672.36\n(-49.4)2 = 2440.36\n(-18.4)2 =  338.56\n(- 0.4)2 =    0.16\n (19.6)2 =  384.16\n '

# %%
#numpy ile varyans bulma:
speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %%
# bu değerlerin standart sapmasını bulmak için
# √1432.25 = 37.85
# standrat sapma σ ile gösterilir
# varyans σ nin karesidir

# %%
# Percentile
# Percentile lar bir dizideki sayıların verdiğiniz yüzdeye göre daha küçük olduğunu gösterir
# örnek bir yaş dizisindeki %75 inin kaçtan küçük olduğunu percentile ile bulabiliriz
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %%
# insanların %90 ının daha küçük olduğu yaş:

# %%
x = numpy.percentile(ages, 90)

print(x)
# Out:
# 61.0

# %%
# Data Distribution
# Gerçek hayatta veri toplamak zor olabilir bunun için
# Random veriler üretiriz
import numpy
# 0.0 dan 5.0 a kadar 250 adet random float veriler ürettik
x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [1.51446426 3.9136218  0.26017628 4.41918014 0.03949467 1.81961905
#  0.34522202 4.05789974 3.16978658 3.08605794 1.65785092 1.78212416
#  1.46519445 3.41269856 0.56197679 2.05021082 3.38241105 3.44315631
#  3.55899757 2.29093994 2.87775156 2.89226016 3.12639391 4.38920244
#  2.03370283 4.30491031 4.45860678 2.37757208 4.15649953 4.45745475
#  1.82787562 2.79849635 1.56336455 1.81113372 3.31575886 1.06362403
#  3.9707756  2.7668277  3.89306545 1.04441606 2.60644105 1.53434223
#  4.1889179  2.05701673 2.54188185 4.82193576 2.13884873 4.85580383
#  1.37951736 1.73388147 2.61299087 0.46793645 3.59130532 2.72570165
#  0.13115531 4.39360418 2.99437768 2.35366317 3.79770564 1.95170942
#  1.84968989 1.21527884 1.99355711 3.63770627 0.76609194 2.34793789
#  0.23084318 1.60515869 4.59003251 1.92075331 0.05958524 1.65194739
#  4.2444116  3.65733101 4.48836492 2.18960688 0.87118319 2.82219463
#  3.463451   0.14121022 1.63770599 0.41430954 0.28011735 2.24018166
#  4.11062652 4.92247727 0.25279669 0.47971392 2.78263775 1.44732097
#  2.22911276 1.98598458 4.83231641 4.3018355  4.5139204  1.49863083
#  1.14258389 1.65881098 0.60474574 2.47661898 4.58103381 1.43653323
#  3.977743   3.89755284 2.28137336 2.1740692  1.30151591 0.46429009
#  1.56959397 2.39988334 3.17984588 4.3925889  1.74210218 4.7259363
#  3.8112784  3.01256019 1.14507705 2.9895564  2.18745073 1.9154556
#  2.22299002 0.14869357 0.60244377 1.69495606 3.15583964 1.72941926
#  4.43117335 2.844813   3.59006168 3.04845385 4.36465148 0.67900596
#  3.20105116 2.47674621 0.35989812 2.3636394  2.19236032 0.6761877
#  2.48504422 3.81028744 1.06589965 1.66207824 0.35484786 2.65606778
#  1.63952497 0.2951341  4.86452273 3.3242353  2.79812521 4.67827639
#  0.77293344 0.98857375 3.5690821  1.1148792  1.85258149 2.29101995
#  0.35128445 1.3926023  3.31532563 4.23665981 3.0987762  4.28777126
#  3.09448863 0.06840605 4.54017295 0.12380706 1.28462131 2.02619013
#  3.01300742 4.03663689 2.57065378 3.10517968 3.31067705 1.34487919
#  1.59883828 3.69905049 4.42681559 0.75984397 3.9209157  4.42768283
#  0.6066828  3.42988182 4.11103887 4.02740904 2.96003928 0.19759835
#  3.48098536 1.82541394 4.64870658 4.94587257 1.65534278 2.31693214
#  0.63826909 3.86515342 0.16540863 3.72110816 1.87104391 2.63064695
#  4.03617205 3.9744278  3.23263011 3.91109664 0.58377882 1.44025199
#  0.42215769 1.93808426 4.04205547 1.88800343 2.64020002 3.24291384
#  0.54840773 0.24206245 0.2608889  1.69063291 0.05137875 2.07311563
#  1.30818622 3.67164483 4.44771929 1.7086209  0.01832198 2.77882057
#  3.30255506 3.92976577 1.69996065 0.36202154 4.59688262 3.39324347
#  0.56602907 2.7517342  1.65777583 0.31182447 0.52777608 2.56880196
#  1.51603879 1.82138772 0.26120215 1.83540754 0.85573371 4.31198667
#  4.79638782 1.0618907  1.09734298 4.75295553 3.24455355 1.85003393
#  4.06741483 1.63746491 0.85871637 3.16170643]

# %%
# histogram verilerimizi görselleştirmek için gerekir
import matplotlib.pyplot as plt
# ilk sütun 0 ile 1 arasındaki sayıları temsil ediyor
x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
#veriler istenildiği kadar büyük olabilir
x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
# Veriler tek bir noktada yoğunluklu da olabilir ve bu tarz veri dağılımna
# Normal Data Distribution veya Gaussian data distribution denir
# ortalama değer 5 ve standart sapma 1
x = numpy.random.normal(5.0, 1.0, 100000)
# 100 satırlı bir histogram çizmek için:
plt.hist(x, 100)
plt.show()

# %%
# Scatter Plot

# %%
#  Scatter Plot her veriyi noktalar şeklinde ekrana çizer
# X ve Y düzlemlerinde değerler verilir
# her x değeri bir arabanın yaşını
# her y değeri bir arabanın hızını göstersin
# bu grafikte en hızlı ve en yavaş arabalar hangi yaş grubundadır ?

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]

y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
# makine öğrenmesinde veri setleri yüz binlerce hatta milyonlarca veriyi tutabilir
# algoritmalarla çalışmak için gerçek hayat verisi bulmak zor olabilir bu yüzden
# rastgele oluşturulmuş veriler kullanırız.
import numpy as np
x= np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
# yayılımın y de daha fazla olduğunu görebiliyoruz

# %%
# Regression

# %%
# Regresyon 2 değişken arasındaki ilişkiyi bulmak için kullanılır
# makine öğrenmesi ve istatistiksel modellemeler gelecekte bize yardımcı olması için tahminlerde bulunurlar.
# Linear Regression veri noktaları arasındaki ilişkileri kullanarak düz bir çizgi çizer
# bu çizgi gelecek tahminleri yapmak için kullanılır

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
